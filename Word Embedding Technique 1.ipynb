# %%
sent=["The world is a better place",
      "Marvel series is my favourite movie",
      "I like DC movies",
      "the cat is eating the food",
      "Tom and Jerry is my favourite movie",
      "Python is my favourite programming language"
      ]

# %%
import tensorflow as tf
import keras
import numpy as np

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent
# Out:
# ['The world is a better place',
#  'Marvel series is my favourite movie',
#  'I like DC movies',
#  'the cat is eating the food',
#  'Tom and Jerry is my favourite movie',
#  'Python is my favourite programming language']

# %%
## Vocalbulary size
voc_size = 1000

# %%
onehot_repr = [one_hot(words, voc_size)for words in sent]
print(onehot_repr)
# Out:
# [[726, 402, 562, 254, 296, 193], [928, 488, 562, 693, 358, 813], [277, 836, 264, 45], [726, 645, 562, 493, 726, 185], [509, 510, 479, 562, 693, 358, 813], [922, 562, 693, 358, 982, 158]]

# %% [markdown]
# ### Word Embedding representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
## Pre padding
sent_length = 10
embedded_docs = pad_sequences(onehot_repr, padding="pre",maxlen=sent_length)
print(embedded_docs)
# Out:
# [[  0   0   0   0 726 402 562 254 296 193]
#  [  0   0   0   0 928 488 562 693 358 813]
#  [  0   0   0   0   0   0 277 836 264  45]
#  [  0   0   0   0 726 645 562 493 726 185]
#  [  0   0   0 509 510 479 562 693 358 813]
#  [  0   0   0   0 922 562 693 358 982 158]]

# %%
### 10 feature dimentions
dim = 20

# %%
model = Sequential()
model.add(Embedding(voc_size,20))
model.build(input_shape=(None, sent_length))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape    ┃   Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ embedding_22           │ (None, 10, 20)  │    20,000 │
# │ (Embedding)            │                 │           │
# └────────────────────────┴─────────────────┴───────────┘
#  Total params: 20,000 (78.12 KB)
#  Trainable params: 20,000 (78.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
embedded_docs[0]
# Out:
# array([  0,   0,   0,   0, 726, 402, 562, 254, 296, 193])

# %%
model.predict(embedded_docs)[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# array([[-0.04058447, -0.00365896,  0.00755948, -0.01040363,  0.02733977,
#         -0.03397676, -0.04711812, -0.01611352,  0.03057737, -0.04580152,
#          0.00641119, -0.00088023, -0.03322577, -0.03401706, -0.03518386,
#          0.03801845, -0.0403735 ,  0.01142615, -0.03957732, -0.03262031],
#        [-0.04058447, -0.00365896,  0.00755948, -0.01040363,  0.02733977,
#         -0.03397676, -0.04711812, -0.01611352,  0.03057737, -0.04580152,
#          0.00641119, -0.00088023, -0.03322577, -0.03401706, -0.03518386,
#          0.03801845, -0.0403735 ,  0.01142615, -0.03957732, -0.03262031],
#        [-0.04058447, -0.00365896,  0.00755948, -0.01040363,  0.02733977,
#         -0.03397676, -0.04711812, -0.01611352,  0.03057737, -0.04580152,
#          0.00641119, -0.00088023, -0.03322577, -0.03401706, -0.03518386,
#          0.03801845, -0.0403735 ,  0.01142615, -0.03957732, -0.03262031],
#        [-0.04058447, -0.00365896,  0.00755948, -0.01040363,  0.02733977,
#         -0.03397676, -0.04711812, -0.01611352,  0.03057737, -0.04580152,
#          0.00641119, -0.00088023, -0.03322577, -0.03401706, -0.03518386,
#          0.03801845, -0.0403735 ,  0.01142615, -0.03957732, -0.03262031],
#        [ 0.0166125 , -0.00763952,  0.02715402,  0.04936223,  0.0308152 ,
#          0.0286221 ,  0.04787426,  0.04912778,  0.04669524, -0.00596218,
#         -0.00033309,  0.02956731,  0.02264019,  0.03474445, -0.00889339,
#         -0.032113  , -0.01821657, -0.03211724, -0.01631213,  0.03534606],
#        [ 0.04829217,  0.00697118, -0.00584377, -0.02627693, -0.00754658,
#         -0.03921667, -0.03332021,  0.01643533,  0.00940139, -0.01453593,
#         -0.01798249,  0.04994819,  0.01439608, -0.01953272, -0.01179384,
#          0.01676747, -0.0424153 ,  0.01047926,  0.04949245, -0.0191042 ],
#        [-0.01978843,  0.02878702, -0.00698012, -0.00197887,  0.03057343,
#         -0.00529379, -0.00923779,  0.01987804, -0.01562338, -0.0014959 ,
#          0.01293007,  0.03281534,  0.00664704, -0.03134684,  0.04653058,
#         -0.0250904 , -0.04195002, -0.04083198,  0.03757392, -0.04468529],
#        [-0.04983488,  0.01097322, -0.02024589, -0.00394641,  0.03450524,
#          0.02819848, -0.01249734, -0.0356129 , -0.01852443,  0.03462906,
#         -0.0075377 ,  0.00918712,  0.04593578,  0.03548861, -0.03354903,
#          0.01466611, -0.00974866,  0.0066219 , -0.04552169, -0.04930016],
#        [ 0.00127977,  0.01891123, -0.02831963, -0.02086278, -0.04738864,
#          0.04191181, -0.00957345, -0.04433976,  0.02247469, -0.01173921,
#          0.01822204,  0.04697648, -0.03819187,  0.01137061,  0.00396486,
#         -0.04386163,  0.00405735,  0.04070215, -0.02545743,  0.03547093],
#        [ 0.02899611,  0.04639241,  0.02996571, -0.00402052,  0.03753065,
#         -0.0494406 ,  0.00457688, -0.04989041, -0.04502384, -0.02369466,
#         -0.02818953,  0.04804523,  0.04842169, -0.0155903 , -0.02822489,
#         -0.04529442,  0.04299885, -0.01537307,  0.03495124,  0.04098858]],
#       dtype=float32)

# %%
print(model.predict(embedded_docs))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[[-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   ...
#   [-0.04983488  0.01097322 -0.02024589 ...  0.0066219  -0.04552169
#    -0.04930016]
#   [ 0.00127977  0.01891123 -0.02831963 ...  0.04070215 -0.02545743
#     0.03547093]
#   [ 0.02899611  0.04639241  0.02996571 ... -0.01537307  0.03495124
#     0.04098858]]
#
#  [[-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   ...
#   [-0.04926204 -0.02109673  0.00915877 ... -0.01281559  0.01116649
#    -0.04927641]
#   [ 0.02888677  0.01175028 -0.02952625 ...  0.00788702 -0.03359983
#    -0.0073471 ]
#   [ 0.030426   -0.0207796  -0.04518897 ...  0.00682454  0.0461689
#    -0.04687965]]
#
#  [[-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   ...
#   [-0.0277596   0.02434738  0.03619604 ...  0.0240425  -0.00936873
#    -0.00178906]
#   [ 0.04957784  0.02829807 -0.0295386  ... -0.01184123 -0.02903461
#    -0.04758679]
#   [-0.02573755  0.01204492  0.04410866 ... -0.03785683 -0.0461524
#     0.00895388]]
#
#  [[-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   ...
#   [ 0.02730398 -0.00894562  0.01267273 ...  0.03701651  0.00151008
#     0.00795553]
#   [ 0.0166125  -0.00763952  0.02715402 ... -0.03211724 -0.01631213
#     0.03534606]
#   [ 0.03631714 -0.01221935 -0.0028236  ... -0.04563253  0.01861512
#     0.00332315]]
#
#  [[-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   ...
#   [-0.04926204 -0.02109673  0.00915877 ... -0.01281559  0.01116649
#    -0.04927641]
#   [ 0.02888677  0.01175028 -0.02952625 ...  0.00788702 -0.03359983
#    -0.0073471 ]
#   [ 0.030426   -0.0207796  -0.04518897 ...  0.00682454  0.0461689
#    -0.04687965]]
#
#  [[-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   [-0.04058447 -0.00365896  0.00755948 ...  0.01142615 -0.03957732
#    -0.03262031]
#   ...
#   [ 0.02888677  0.01175028 -0.02952625 ...  0.00788702 -0.03359983
#    -0.0073471 ]
#   [-0.03013859 -0.01930525 -0.01725609 ... -0.01093714 -0.01018221
#     0.04652078]
#   [ 0.02558229  0.02032124 -0.02632037 ... -0.00869445  0.0308168
#     0.01009495]]]

# %%
print(model.predict(embedded_docs)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [